# %% [markdown]
# # EXERCÍCIOS

# %% [markdown]
# Gerar um mapa com a classificação dos municípios do Estado de Tocantins em relação ao número de focos ocorridos no mês de setembro de 2016.

# %%
# encoding: utf-8
# %matplotlib inline
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
focos = gpd.read_file("/home/labgeo6/Willian/PythonGilberto/Focos2016/Focos.2016-01-01.2016-12-31.shp")
#focos.dtypes

# %%
focos["timestamp"] = pd.to_datetime(focos["DataHora"])

# %%
focos_to = focos[focos.Estado == 'Tocantins']
focos_to_set = focos_to[focos.timestamp.dt.month == 9]
# Out:
# /home/labgeo6/anaconda2/envs/geospatial/lib/python2.7/site-packages/geopandas/geodataframe.py:398: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super(GeoDataFrame, self).__getitem__(key)

# %%
focos_to_set.head(2)
# Out:
#                   DataHora  Satelite    Pais     Estado  Municipi    Bioma  \
# 84977  2016/09/01 16:04:38  AQUA_M-T  Brasil  Tocantins  Goiatins  Cerrado
# 84996  2016/09/01 16:04:38  AQUA_M-T  Brasil  Tocantins  Goiatins  Cerrado
#
#        DiaSemCh  Precipit  RiscoFog  Latitude  Longitud AreaIndu  FRP  \
# 84977        40       0.3       1.0    -8.048   -47.666           0.0
# 84996        40       0.3       1.0    -8.047   -47.670           0.0
#
#                                 geometry           timestamp
# 84977             POINT (-47.666 -8.048) 2016-09-01 16:04:38
# 84996  POINT (-47.67 -8.047000000000001) 2016-09-01 16:04:38

# %% [markdown]
# # Importando o Shapefile de municípios do IBGE

# %%
#Base de municípios do IBGE
municipios = gpd.read_file("/home/labgeo6/Willian/PythonGilberto/Municipios_BR/BRMUE250GC_SIR.shp")

# %%
#Tocantins: 17
#Minas Gerais: 31
#Rio Grande do Sul:43

#Separando apenas os municípios do estado do Tocantins
munic_to = municipios[municipios["CD_GEOCMU"].str[0:2] == "17"]

# %%
#Como os Sistema de Referência são diferentes....
focos_to_set.crs = {'init': 'epsg:4326'}
munic_to.crs = {'init': 'epsg:4326'}

# %%
# Agrupando os dados
To_join = gpd.sjoin(focos_to_set, munic_to, how="right", op='intersects')

# %%
To_join.head(2)
# Out:
#              index_left             DataHora  Satelite    Pais     Estado  \
# index_right
# 366             84977.0  2016/09/01 16:04:38  AQUA_M-T  Brasil  Tocantins
# 366             84996.0  2016/09/01 16:04:38  AQUA_M-T  Brasil  Tocantins
#
#              Municipi    Bioma  DiaSemCh  Precipit  RiscoFog  Latitude  \
# index_right
# 366          Goiatins  Cerrado      40.0       0.3       1.0    -8.048
# 366          Goiatins  Cerrado      40.0       0.3       1.0    -8.047
#
#              Longitud AreaIndu  FRP           timestamp NM_MUNICIP CD_GEOCMU  \
# index_right
# 366           -47.666           0.0 2016-09-01 16:04:38   GOIATINS   1709005
# 366           -47.670           0.0 2016-09-01 16:04:38   GOIATINS   1709005
#
#                                                       geometry
# index_right
# 366          POLYGON ((-47.43492963199998 -7.55911717699996...
# 366          POLYGON ((-47.43492963199998 -7.55911717699996...

# %%
munic_to_2 = munic_to.set_index('NM_MUNICIP')

# %%
#focos_selected = To_join.groupby("Municipi").Municipi.count()
focos_selected = To_join.groupby("NM_MUNICIP").Municipi.count()

focos_selected.index.name = "Municipios"
focos_selected.name = "Numero de focos por municipio em Tocantins, para Setembro de 2016"
focos_selected.head()
# Out:
# Municipios
# ABREULÂNDIA             50
# AGUIARNÓPOLIS            0
# ALIANÇA DO TOCANTINS    19
# ALMAS                   42
# ALVORADA                 1
# Name: Numero de focos por municipio em Tocantins, para Setembro de 2016, dtype: int64

# %%
focos_to_mu = pd.concat([munic_to_2, focos_selected], axis=1)
focos_to_mu.head()
# Out:
#                      CD_GEOCMU  \
# ABREULÂNDIA            1700251
# AGUIARNÓPOLIS          1700301
# ALIANÇA DO TOCANTINS   1700350
# ALMAS                  1700400
# ALVORADA               1700707
#
#                                                                geometry  \
# ABREULÂNDIA           POLYGON ((-49.39149645199996 -9.17452846299994...
# AGUIARNÓPOLIS         POLYGON ((-47.57648308799997 -6.41472972499997...
# ALIANÇA DO TOCANTINS  POLYGON ((-48.71252417899996 -11.1699301449999...
# ALMAS                 POLYGON ((-47.26256828099997 -10.9813311369999...
# ALVORADA              POLYGON ((-49.03874863299995 -12.2244394629999...
#
#                       Numero de focos por municipio em Tocantins, para Setembro de 2016
# ABREULÂNDIA                                                          50
# AGUIARNÓPOLIS                                                         0
# ALIANÇA DO TOCANTINS                                                 19
# ALMAS                                                                42
# ALVORADA                                                              1

# %%
mapaFocos = focos_to_mu.plot(column='Numero de focos por municipio em Tocantins, para Setembro de 2016', \
                              figsize = (20, 15), k=6, legend = True, scheme = 'Fisher_jenks')

mapaFocos.plot();
